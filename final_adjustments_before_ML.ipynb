# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
path = "/content/post_feature_engineering.csv"
df = pd.read_csv(path)

# %%
df
# Out:
#      Unnamed: 0  dependents  education  self_employed  applicant_income  \
# 0             0           0          0              0              5849
# 1             1           1          0              0              4583
# 2             2           0          0              1              3000
# 3             3           0          1              0              2583
# 4             4           0          0              0              6000
# ..          ...         ...        ...            ...               ...
# 609         609           0          0              0              2900
# 610         610           4          0              0              4106
# 611         611           1          0              0              8072
# 612         612           2          0              0              7583
# 613         613           0          0              1              4583
#
#      coapplicant_income  loan_amount_term  credit_history  property_area  \
# ...

# %%
print(df.duplicated().sum())
# there is a duplicate so we drop it
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
columns_to_drop = ['applicant_income', 'coapplicant_income', 'TotalIncome']
# Drop them using axis=1 (which means "columns")
df = df.drop(columns_to_drop, axis=1)

# %%
df
# Out:
#      Unnamed: 0  dependents  education  self_employed  loan_amount_term  \
# 0             0           0          0              0             360.0
# 1             1           1          0              0             360.0
# 2             2           0          0              1             360.0
# 3             3           0          1              0             360.0
# 4             4           0          0              0             360.0
# ..          ...         ...        ...            ...               ...
# 609         609           0          0              0             360.0
# 610         610           4          0              0             180.0
# 611         611           1          0              0             360.0
# 612         612           2          0              0             360.0
# 613         613           0          0              1             360.0
#
#      credit_history  property_area  loan_status  TotalIncome_log  \
# ...

# %%
df.rename(columns={'TotalIncome_log': 'total_income_log'},inplace=True)
df
# Out:
#      Unnamed: 0  dependents  education  self_employed  loan_amount_term  \
# 0             0           0          0              0             360.0
# 1             1           1          0              0             360.0
# 2             2           0          0              1             360.0
# 3             3           0          1              0             360.0
# 4             4           0          0              0             360.0
# ..          ...         ...        ...            ...               ...
# 609         609           0          0              0             360.0
# 610         610           4          0              0             180.0
# 611         611           1          0              0             360.0
# 612         612           2          0              0             360.0
# 613         613           0          0              1             360.0
#
#      credit_history  property_area  loan_status  total_income_log  \
# ...

# %%
df.to_csv('ML_ready.csv', index=False)
